# %% [markdown]
# # Visualize Centerpoint Heatmap

# %%
import jupyterlab
print(jupyterlab.__version__)
# Out:
# 4.6.1

# %%
import json
from pathlib import Path
import plotly.graph_objects as go
from pyquaternion import Quaternion

# %%
metrics_summary = json.load(open("../results/pointpillars_fpn/preds/pred_instances_3d/metrics_summary.json"))

metrics_summary["mean_ap"], metrics_summary["nd_score"]
# Out:
# (0.3760941358595121, 0.4539920318497465)

# %%
metrics_summary = json.load(open("../results/centerpoint_pillar/preds/pred_instances_3d/metrics_summary.json"))

metrics_summary["mean_ap"], metrics_summary["nd_score"]
# Out:
# (0.41158390521575294, 0.4821113711859118)

# %%
metrics_summary = json.load(open("../results/pointpillars_secfpn/preds/pred_instances_3d/metrics_summary.json"))

metrics_summary["mean_ap"], metrics_summary["nd_score"]
# Out:
# (0.3262327202804408, 0.40763286387834635)

# %% [markdown]
# # Vast

# %%
metrics_summary = json.load(open("../results/vast/centerpoint_01voxel/preds/pred_instances_3d/metrics_summary.json"))

metrics_summary["mean_ap"], metrics_summary["nd_score"]
# Out:
# (0.554383964846743, 0.6408627654769912)

# %%
metrics_summary = json.load(open("../results/vast/centerpoint_0075voxel/preds/pred_instances_3d/metrics_summary.json"))

metrics_summary["mean_ap"], metrics_summary["nd_score"]
# Out:
# (0.55854056648426, 0.6456651958061145)

# %%
metrics_summary = json.load(open("../results/vast/pointpillars_fpn/preds/pred_instances_3d/metrics_summary.json"))

metrics_summary["mean_ap"], metrics_summary["nd_score"]
# Out:
# (0.3901449617878956, 0.5263688517501364)

# %%
metrics_summary = json.load(open("../results/vast/pointpillars_secfpn/preds/pred_instances_3d/metrics_summary.json"))

metrics_summary["mean_ap"], metrics_summary["nd_score"]
# Out:
# (0.3369007084750385, 0.4853573311662213)

# %%
metrics_summary = json.load(open("../results/vast/centerpointpillars/preds/pred_instances_3d/metrics_summary.json"))

metrics_summary["mean_ap"], metrics_summary["nd_score"]
# Out:
# (0.4812711925177176, 0.5900870702270705)

# %%
metrics_summary = json.load(open("../results/vast/bevfusion_lidar/preds/pred_instances_3d/metrics_summary.json"))

metrics_summary["mean_ap"], metrics_summary["nd_score"]
# Out:
# (0.6436783099178844, 0.6917042484736908)

# %%
metrics_summary = json.load(open("../results/vast/bevfusion_lidar_cam/preds/pred_instances_3d/metrics_summary.json"))

metrics_summary["mean_ap"], metrics_summary["nd_score"]
# Out:
# (0.6838151741637896, 0.7118716444614879)

# %%
metrics_summary = json.load(open("../results/vast/petr/preds/pred_instances_3d/metrics_summary.json"))

metrics_summary["mean_ap"], metrics_summary["nd_score"]
# Out:
# (0.3829986196765453, 0.3912213524236572)
